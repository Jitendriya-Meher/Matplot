# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,8])
y = np.array([3,10])

plt.plot(x,y)
plt.show()

# %%
x = np.array([1,4,8])
y = np.array([3,5,10])

plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([1,2,5,6])
y = np.array([3,10,0,20])

plt.plot(x,y)
plt.show()

# %%
y = np.array([3,8,1,10,5,9])

plt.plot(y)
plt.show()
