# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.array([1,9,2,8,3,7,4,6,5])

plt.plot(y, linestyle='dotted')

# %%
plt.plot(y, ls='--', c='r', lw=5)

# %%
x = np.array([9,2,8,6,5])
z = np.array([1,2,3,4,5,5,6,7])
plt.plot(y)
plt.plot(x)
plt.plot(z)
