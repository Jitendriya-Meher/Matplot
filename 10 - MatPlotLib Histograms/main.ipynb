# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.normal(170,20,250)

plt.hist(x,color="red")
# Out:
# (array([ 8., 14., 26., 51., 66., 49., 27.,  7.,  0.,  2.]),
#  array([116.75440415, 128.71384633, 140.6732885 , 152.63273068,
#         164.59217286, 176.55161503, 188.51105721, 200.47049938,
#         212.42994156, 224.38938373, 236.34882591]),
#  <BarContainer object of 10 artists>)
