# %%
import matplotlib
import numpy as np

# %%
matplotlib.__version__
# Out:
# '3.6.2'

# %%
# pyplot sub module
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([10,5,20,10,30,15])

plt.plot(x,y)
plt.show()

# %%
x = np.array([0,3,6])
y = np.array([0,200,250])
print(x)

plt.plot(x,y)
# Out:
# [0 3 6]
