# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(["a",'b','c','d','e'])
y = np.array([10,3,1,20,30])

plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
colors = ["red",'cyan','yellow','pink','green']
plt.bar(x,y,color=colors)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x,y,width=0.2)
# Out:
# <BarContainer object of 5 artists>
