# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.array([1,9,0,30,15,8,16])

plt.plot(y)

# %%
plt.plot(y, marker='o')

# %%
plt.plot(y, marker='*')

# %%
plt.plot(y, 'o:r' )

# %%
plt.plot(y, 'o-g' )

# %%
plt.plot(y, 'o--c' )

# %%
plt.plot(y, 'o m' )

# %%
plt.plot(y, 'o:y' ,ms=20,mfc='r')

# %%
plt.plot(y, 'o:k' ,ms=10 , mec='b' ,mfc='w')
